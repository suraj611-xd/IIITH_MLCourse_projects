# %% [markdown]
# <a href="https://colab.research.google.com/github/suraj611-xd/IIITH_MLCourse_projects/blob/main/IIITH_ML_Projects_Labs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World
